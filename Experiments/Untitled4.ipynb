# %%
#Simplicial complex parameters
N = 211
k1 = 25
k2 = 4
k3=1

#Infection parameters
mu = 0.1
lambda1s = np.linspace(0.2,2.2,30)
lambdaD_target_list = [4]
lambdaS_target_list = [1]
I_percentage_list = [40] #initial conditions (% of infected)

fig = plt.figure(figsize=(4.5,3));
markers = ['s']
zorders = [8]
mfcs = ['grey']
lables = [r'$\lambda_\Delta=0$']
markersizes = [5]


out_dir = 'Results108/'

# !mkdir ./Results108


ax = plt.subplot(111)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.set_xlabel(r'Rescaled infectivity, $\lambda_{S_1}$', size=16)
ax.set_ylabel(r'Density of infected nodes, $\rho^{*}$', size=16)
ax.set_xlim(0.2,2.2)
ax.set_ylim(-0.01,0.8);
ax.set_yticks([0,0.2,0.4,0.6,0.8]);

# To add the legend box!!!!
h3 = plt.plot([],[],'o', color='grey', markersize=7.5, label='$\lambda_{S_2}=4$; $\lambda_{S_3}=1$')
lgd = plt.legend(handles=h3, loc=(0.02,0.82), frameon=False, fontsize=14, handlelength=1, borderpad=0.1)
ax.add_artist(lgd)



ax.annotate('SIS', (2,0.38), fontsize=13)

for i, (lambdaD_target, I_percentage) in enumerate(zip(lambdaD_target_list, I_percentage_list)):
    for lambdaS_target in lambdaS_target_list:
        filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_kS'+str(k3)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_lS'+str(lambdaS_target)+'_seed'+str(I_percentage)+'.p' 
        results = pickle.load(open(out_dir+filename,"rb" ))
        avg_rhos, avg_k, avg_kD, avg_kS = results
    #     print(avg_rhos)
        ax.plot(lambda1s, avg_rhos, markers[i], color='black', zorder=zorders[i], mfc=mfcs[i], markersize=markersizes[i], label=lables[i])
        fig.subplots_adjust(bottom=0.1)
        plt.savefig('output.png', dpi=300, bbox_inches='tight')
    #     if i != 1:
    #         m=MF_y_dict[i](MF_X)
    #         ax.plot(MF_x, m, '-', markersize=2, color=u'#ff7f0e')
# Out:
# mkdir: ./Results108: File exists

# %%
#Simplicial complex parameters
N = 251
k1 = 25
k2 = 4
k3=1

#Infection parameters
mu = 0.06
lambda1s = np.linspace(0.2,2.2,30)
lambdaD_target_list = [4]
lambdaS_target_list = [10]
I_percentage_list = [1] #initial conditions (% of infected)

fig = plt.figure(figsize=(4.5,3));
markers = ['s']
zorders = [8]
mfcs = ['grey']
lables = [r'$\lambda_\Delta=0$']
markersizes = [5]


out_dir = 'Results113/'

# !mkdir ./Results113


ax = plt.subplot(111)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.set_xlabel(r'Rescaled infectivity, $\lambda_{S_1}$', size=16)
ax.set_ylabel(r'Density of infected nodes, $\rho^{*}$', size=16)
ax.set_xlim(0.2,2.2)
ax.set_ylim(-0.01,0.8);
ax.set_yticks([0,0.2,0.4,0.6,0.8]);

# To add the legend box!!!!
h3 = plt.plot([],[],'o', color='grey', markersize=7.5, label='$\lambda_{S_2}=4$; $\lambda_{S_3}=10$')
lgd = plt.legend(handles=h3, loc=(0.02,0.82), frameon=False, fontsize=14, handlelength=1, borderpad=0.1)
ax.add_artist(lgd)



ax.annotate('SIS', (2,0.38), fontsize=13)

for i, (lambdaD_target, I_percentage) in enumerate(zip(lambdaD_target_list, I_percentage_list)):
    for lambdaS_target in lambdaS_target_list:
        filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_kS'+str(k3)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_lS'+str(lambdaS_target)+'_seed'+str(I_percentage)+'.p' 
        results = pickle.load(open(out_dir+filename,"rb" ))
        avg_rhos, avg_k, avg_kD, avg_kS = results
    #     print(avg_rhos)
        ax.plot(lambda1s, avg_rhos, markers[i], color='black', zorder=zorders[i], mfc=mfcs[i], markersize=markersizes[i], label=lables[i])
        fig.subplots_adjust(bottom=0.1)
        plt.savefig('output.png', dpi=300, bbox_inches='tight')
    #     if i != 1:
    #         m=MF_y_dict[i](MF_X)
    #         ax.plot(MF_x, m, '-', markersize=2, color=u'#ff7f0e')
# Out:
# mkdir: ./Results113: File exists

# %%
#Simplicial complex parameters
N = 251
k1 = 25
k2 = 4
k3=1

#Infection parameters
mu = 0.06
lambda1s = np.linspace(0.2,2.2,30)
lambdaD_target_list = [4]
lambdaS_target_list = [1]
I_percentage_list = [40] #initial conditions (% of infected)

fig = plt.figure(figsize=(4.5,3));
markers = ['s']
zorders = [8]
mfcs = ['grey']
lables = [r'$\lambda_\Delta=0$']
markersizes = [5]


out_dir = 'Results110/'

# !mkdir ./Results110


ax = plt.subplot(111)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.set_xlabel(r'Rescaled infectivity, $\lambda_{S_1}$', size=16)
ax.set_ylabel(r'Density of infected nodes, $\rho^{*}$', size=16)
ax.set_xlim(0.2,2.2)
ax.set_ylim(-0.01,0.8);
ax.set_yticks([0,0.2,0.4,0.6,0.8]);

# To add the legend box!!!!
h3 = plt.plot([],[],'o', color='grey', markersize=7.5, label='$\lambda_{S_2}=4$; $\lambda_{S_3}=10$')
lgd = plt.legend(handles=h3, loc=(0.02,0.82), frameon=False, fontsize=14, handlelength=1, borderpad=0.1)
ax.add_artist(lgd)



ax.annotate('SIS', (2,0.38), fontsize=13)

for i, (lambdaD_target, I_percentage) in enumerate(zip(lambdaD_target_list, I_percentage_list)):
    for lambdaS_target in lambdaS_target_list:
        filename = 'result_RSC_'+'N'+str(N)+'_k'+str(k1)+'_kD'+str(k2)+'_kS'+str(k3)+'_mu'+str(mu)+'_lD'+str(lambdaD_target)+'_lS'+str(lambdaS_target)+'_seed'+str(I_percentage)+'.p' 
        results = pickle.load(open(out_dir+filename,"rb" ))
        avg_rhos, avg_k, avg_kD, avg_kS = results
    #     print(avg_rhos)
        ax.plot(lambda1s, avg_rhos, markers[i], color='black', zorder=zorders[i], mfc=mfcs[i], markersize=markersizes[i], label=lables[i])
        fig.subplots_adjust(bottom=0.1)
        plt.savefig('output.png', dpi=300, bbox_inches='tight')
    #     if i != 1:
    #         m=MF_y_dict[i](MF_X)
    #         ax.plot(MF_x, m, '-', markersize=2, color=u'#ff7f0e')
# Out:
# mkdir: ./Results110: File exists

# %%
cd Desktop/Harvard Hypergraphs
# Out:
# [Errno 2] No such file or directory: 'Desktop/Harvard Hypergraphs'
# /Users/pellegrinraphael/Desktop/Harvard Hypergraphs/Code for squares - in progress

# %%
cd Code for squares - in progress
# Out:
# /Users/pellegrinraphael/Desktop/Harvard Hypergraphs/Code for squares - in progress

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
cd
# Out:
# /Users/pellegrinraphael

# %%
ls
# Out:
# Adlm/                      ex2.synctex.gz(busy)
# Applications/              ex2.tex
# Desktop/                   example.hs
# Documents/                 haskellcrypto_rpp16/
# Downloads/                 haskellsequences_rpp16/
# Library/                   livre.py
# Movies/                    matlab_crash_dump.17060-1
# Music/                     matlab_crash_dump.78546-1
# Pictures/                  nullstellensatz/
# Prezi/                     opt/
# Prime95/                   output.png
# Public/                    scikit_learn_data/
# Results/                   tmp2.pdf
# Rplot01.pdf                untitled-1.pdf
# Sites/                     untitled-10.aux
# Untitled.R                 untitled-10.log
# Vins contactés.txt         untitled-10.pdf
# config.log                 untitled-10.synctex.gz
# ex2.aux                    untitled-10.tex
# ex2.log                    untitled0.py
# ex2.pdf                    untitled4.py
# ex2.synctex.gz

# %%
cd Desktop
# Out:
# /Users/pellegrinraphael/Desktop

# %%
ls
# Out:
# 0.jpg
# AI/
# AM207_HW6.ipynb
# BST232.pdf
# CV/
# Chazala.pdf
# Dossier/
# General/
# HW5/
# Harvard/
# Harvard Hypergraphs/
# IMG_2977.jpg
# IMG_3313.JPG
# IMG_8484.jpeg
# Langue/
# Lecture_7/
# MILA/
# Mihai and Kevin/
# Oxford à trier/
# Passwords.pages
# PhD /
# Python_tutorial.ipynb
# Raph & Wawrinka.jpg
# SIR_practice.ipynb
# Shard.jpg
# Studies/
# Summerproject.ipynb
# Theo/
# Timetable.pages*
# ZC05.pdf
# am205hw5RP.pdf
# description.png
# f436054ad4e780016f1a4420bfd0ffa6.jpg
# file.png
# problem_set_4.html
# rox.png
# simplagion-master/
# stats/
# test.png
# ~$C2.docx
# ~$CV.pptx
# ~$ClasseurG .xlsx
# ~$Deci.docx
# ~$MC coursework .docx
# ~$Poster.docx
# ~$Today.docx
# ~$an pour Noel.docx
# ~$che 5 - Statuts type pour initiative locale.docx
# ~$e soir.docx
# ~$elkirk.docx
# ~$llegrin Raphael Python Coursework 1 (Autosaved) BON.docx
# ~$llegrin Raphael Python Coursework 1 (Autosaved).docx
# ~$llegrin Raphael Python Coursework 1.docx
# ~$nres minimises.docx
# ...

# %%
cd Harvard Hypergraphs
# Out:
# /Users/pellegrinraphael/Desktop/Harvard Hypergraphs

# %%
ls
# Out:
# Code for squares - in progress/ Codes for pentagons/
# Code for triangles/

# %%
cd Code\ for\ squares\ -\ in\ progress
# Out:
# /Users/pellegrinraphael/Desktop/Harvard Hypergraphs/Code for squares - in progress

# %%
ls
# Out:
# Harvard.ipynb*              Results108/
# Results101/                 Results109/
# Results102/                 Results99/
# Results103/                 __pycache__/
# Results104/                 output.png
# Results105/                 simplex_utils.py*
# Results106/                 utils_simplagion_on_RSC.py*
# Results107/
